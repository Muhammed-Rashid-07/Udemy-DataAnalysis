# %% [markdown]
# # Udemy DataAnalysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("udemy_courses.csv",parse_dates=['published_timestamp'])
data
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %% [markdown]
# # Data shape

# %%
data.shape
# Out:
# (3678, 12)

# %% [markdown]
# # All information of datatypes number of rows,11number of columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %% [markdown]
# # Checking null values

# %%
data.isnull().values.any()
# Out:
# False

# %%
sns.heatmap(data=data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# #  Check for duplicate data

# %%
dup = data.duplicated().any()
dup

# %%
data = data.drop_duplicates()
data.duplicated().any()
# Out:
# False

# %% [markdown]
# ## 1. Find number of courses per subject

# %%
data.subject.value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
sns.countplot(data=data,x="subject")
plt.xticks(rotation=45)
plt.title("Number of course in each Category")
# Out:
# Text(0.5, 1.0, 'Number of course in each Category')

# %% [markdown]
# ## 2. Which course has highest Subscribers ?

# %%
popular = data.sort_values(by="num_subscribers",ascending=False).head(10)
popular
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# 1896      19421              Free Beginner Electric Guitar Lessons
# 2589     473160  Web Design for Web Developers: Build Beautiful...
# 2619      94430             Learn Javascript & JQuery From Scratch
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...
# 3247     364426          JavaScript: Understanding the Weird Parts
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# ...

# %%
sns.barplot(data=popular,y="course_title",x="num_subscribers")
plt.title("Top 10 courses which have high subscribers")
# Out:
# Text(0.5, 1.0, 'Top 10 courses which have high subscribers')

# %% [markdown]
# ## 3. Which are the levels provided by udemy?

# %%
data.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
data.level.value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
sns.countplot(data=data,x="level")
plt.xlabel("Level",fontsize=20)
plt.ylabel("Number of courses",fontsize=20)
plt.title("Courses provided in each level")
plt.xticks(rotation=65)
plt.show()

# %% [markdown]
# ## 4. Count of Paid courses and Free courses?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.is_paid.value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
sns.countplot(data=data,x="is_paid")
plt.title("Courses in Free and Paid courses")
# Out:
# Text(0.5, 1.0, 'Courses in Free and Paid courses')

# %% [markdown]
# ## 5. Which course have higher number of subscribers free or paid?

# %%
data.groupby("is_paid")["num_subscribers"].mean()
# Out:
# is_paid
# False    11533.951613
# True      2421.270077
# Name: num_subscribers, dtype: float64

# %%
print("Free courses have more subscribers than paid courses")
# Out:
# Free courses have more subscribers than paid courses

# %%
sns.barplot(x="is_paid",y="num_subscribers",data=data)
plt.title("Subscribers in Free and paid Course")
# Out:
# Text(0.5, 1.0, 'Subscribers in Free and paid Course')

# %% [markdown]
# ## 6. Find 10 Most popular course Title As per Number of Subscribers

# %%
popular.course_title
# Out:
# 2827                 Learn HTML5 Programming From Scratch
# 3032                       Coding for Entrepreneurs Basic
# 3230                           The Web Developer Bootcamp
# 2783    Build Your First Website in 1 Week with HTML5 ...
# 3232                The Complete Web Developer Course 2.0
# 1896                Free Beginner Electric Guitar Lessons
# 2589    Web Design for Web Developers: Build Beautiful...
# 2619               Learn Javascript & JQuery From Scratch
# 3289    Practical PHP: Master the Basics and Code Dyna...
# 3247            JavaScript: Understanding the Weird Parts
# Name: course_title, dtype: object

# %% [markdown]
# ## 7. Which course has high content duration?

# %%
highest_duration_course = data.sort_values(by="content_duration",ascending=False).head()
highest_duration_course
# Out:
#       course_id                                       course_title  \
# 1658     978576              The Complete Figure Drawing Course HD
# 3141     548278  The Complete Web Development Course -  Build 1...
# 561      375594            Financial Management - A Complete Study
# 874      167316            TRADER BOT: Introdução à Linguagem MQL5
# 1214      62721  Anatomy for Figure Drawing: Mastering the Huma...
#
#                                                     url  is_paid  price  \
# 1658  https://www.udemy.com/the-complete-figure-draw...     True     50
# 3141  https://www.udemy.com/complete-web-development...     True    200
# 561   https://www.udemy.com/financial-management-a-c...     True    190
# 874                   https://www.udemy.com/intro-mql5/     True     20
# 1214  https://www.udemy.com/anatomy-for-figure-drawi...     True     95
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# ## 8. Which course has more lectures?

# %%
high_lectures = data.sort_values(by="num_lectures",ascending=False).head()
high_lectures
# Out:
#       course_id                                       course_title  \
# 2707      79154  Back to School Web Development and Programming...
# 160      543242                            Learn to Trade The News
# 2748     978728  Thoughtful Web Development Course: HTML, Vue.j...
# 561      375594            Financial Management - A Complete Study
# 3004     481696  Code & Grow Rich:  Earn More As An Entrepreneu...
#
#                                                     url  is_paid  price  \
# 2707  https://www.udemy.com/back-to-school-web-devel...     True    200
# 160      https://www.udemy.com/learn-to-trade-the-news/     True    200
# 2748  https://www.udemy.com/web-development-html5-cs...     True    200
# 561   https://www.udemy.com/financial-management-a-c...     True    190
# 3004  https://www.udemy.com/code-grow-rich-earn-more...     True    200
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# ## 9. Which course has high price?

# %%
high_price = data.sort_values(by="price",ascending=False).head(15)
high_price
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 3409     552198  Complete Login and Registration System in PHP ...
# 2653     399228  Learn to code, Become a Web Developer and Mast...
# 2651     929016                  HTML and HTML5 For Beginners 2016
# 304      628944  Situational Trading: Proven Option Strategy fo...
# 2636     473548  PHP OOP: Object Oriented Programming for begin...
# 3404    1198704                     How to become an App Developer
# 2631    1181900   Interactive Dynamic JavaScript for beginners DOM
# 2624    1189288  Drupal Tutorial : Drupal 8 Beginner to Expert ...
# 2621     629142            The Ultimate Web Developer How To Guide
# 951     1022796                                Trading for winning
# 2613     140238  Become a Professional Web Developer | Version 3.0
# 2738     789324  Complete Web Development Course + Building 5 W...
# ...

# %%
sns.barplot(data=high_price,y="course_title",x="price",width=0.8)
plt.xlabel("Price",fontsize=20)
plt.ylabel("Courses",fontsize=20)
# Out:
# Text(0, 0.5, 'Courses')

# %% [markdown]
# ## 10. Find the course having high number of reviews?

# %%
high_reviews = data.sort_values(by="num_reviews",ascending=False).head(10)
high_reviews["num_reviews"]
# Out:
# 3230    27445
# 3232    22412
# 3204    19649
# 3247    16976
# 3254    15117
# 3246    11580
# 3251    11123
# 2827     8629
# 3228     8341
# 1979     7676
# Name: num_reviews, dtype: int64

# %%
sns.barplot(data=high_reviews,y="course_title",x="num_reviews",width=0.8)
plt.title("Course which have high reviews")
plt.xlabel("Reviews",fontsize=20)
plt.ylabel("Course",fontsize=20)
# Out:
# Text(0, 0.5, 'Course')

# %% [markdown]
# ## 11. Which course has more lectures Free or paid?

# %%
data.groupby("is_paid")["num_lectures"].mean()

# %%
sns.barplot(data=data,x="is_paid",y="num_lectures")
# Out:
# <Axes: xlabel='is_paid', ylabel='num_lectures'>

# %% [markdown]
# ## 12. Which subject has highest subscribers?

# %%
subject = data.groupby("subject")["num_subscribers"].sum()
subject
# Out:
# subject
# Business Finance       1868711
# Graphic Design         1063148
# Musical Instruments     846689
# Web Development        7937287
# Name: num_subscribers, dtype: int64

# %%
sns.barplot(data=data,y="subject",x="num_subscribers")
plt.xlabel("Subscribers")
plt.title("Which Category has high subscribers?")
# Out:
# Text(0.5, 1.0, 'Which Category has high subscribers?')

# %% [markdown]
# ## 13. Does Price Affect Number of Reviews?

# %%
data.columns

# %%
sns.scatterplot(data=data,x="price",y="num_reviews")
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %%
data.price.unique()

# %% [markdown]
# ## 14. Does price Affect number of subscribers?

# %%
sns.scatterplot(data=data,x="price",y="num_subscribers")
# Out:
# <Axes: xlabel='price', ylabel='num_subscribers'>

# %% [markdown]
# ## 15. Find the total number of courses related to python?

# %%
no_of_python = data[data["course_title"].str.contains('Python',case=False)].head(10)
no_of_python.sort_values(by="num_subscribers",ascending=False,inplace=True)

# %% [markdown]
# ## 16. Top 10 python courses

# %%
sns.barplot(data=no_of_python,y="course_title",x="num_subscribers")
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# ## 17. Top 10 js course?

# %%
no_of_js  = data[data["course_title"].str.contains('javascript',case=False)].head(10)
no_of_js.sort_values(by="num_subscribers",ascending=False,inplace=True)

# %%
sns.barplot(data=no_of_js,y="course_title",x="num_subscribers")
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# ## 18. Top 10 web courses

# %%
sns.barplot(data=no_of_web,y="course_title",x="num_subscribers")
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# ## 19. Top 10 finance courses in udemy

# %%
no_of_finance = data[data["course_title"].str.contains('finance',case=False)].head(10)
no_of_finance.sort_values(by="num_subscribers",ascending=False,inplace=True)

# %%
sns.barplot(data=no_of_finance, y="course_title",x="num_subscribers")
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %%
data.level.unique()
data1 = pd.get_dummies(data=data,columns=["level"],drop_first=True)
data1
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
data.subject
# Out:
# 0       Business Finance
# 1       Business Finance
# 2       Business Finance
# 3       Business Finance
# 4       Business Finance
#               ...
# 3673     Web Development
# 3674     Web Development
# 3675     Web Development
# 3676     Web Development
# 3677     Web Development
# Name: subject, Length: 3672, dtype: object

# %% [markdown]
# ## 20. Is there any relation between level and number of subscribers?

# %%
sns.scatterplot(data=data,x="level",y="num_subscribers")
# Out:
# <Axes: xlabel='level', ylabel='num_subscribers'>

# %% [markdown]
# ## 21. Is there any relation between content duration and number of subscribers?

# %%
sns.scatterplot(data=data,x="content_duration",y="num_subscribers")
# Out:
# <Axes: xlabel='content_duration', ylabel='num_subscribers'>

# %% [markdown]
# ## 22. In which year the highest Number of courses were posted?

# %%
data["year"]=data['published_timestamp'].dt.year
data["year"].value_counts()
# Out:
# C:\Users\MUHAMMED RASHID\AppData\Local\Temp\ipykernel_33000\2118126406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["year"]=data['published_timestamp'].dt.year
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: year, dtype: int64

# %%
sns.countplot(data=data,x="year")
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# ## 23. How many courses of each subject posted in an year?

# %%
year_subject = data.groupby("subject")["year"].value_counts()
year_subject
# Out:
# subject              year
# Business Finance     2016    347
#                      2015    339
#                      2017    223
#                      2014    192
#                      2013     84
#                      2012      6
# Graphic Design       2016    181
#                      2015    168
#                      2017    155
#                      2014     65
#                      2013     23
#                      2012     10
# Musical Instruments  2016    228
#                      2015    171
#                      2014    120
#                      2017    112
#                      2013     39
#                      2012     10
# Web Development      2016    448
#                      2015    336
#                      2017    223
#                      2014    113
#                      2013     55
#                      2012     19
#                      2011      5
# Name: year, dtype: int64

# %% [markdown]
# ## 24. How many subscribers are there in each year?

# %%
year_subscribers = data.groupby("year")["num_subscribers"].sum()
year_subscribers
# Out:
# year
# 2011     119028
# 2012     555339
# 2013    1680153
# 2014    1930406
# 2015    3475324
# 2016    2966644
# 2017     988941
# Name: num_subscribers, dtype: int64

# %%
plt.bar(year_subscribers.index, year_subscribers.values)
plt.title("Number of Subscribers by Year")
plt.xlabel("Year")
plt.ylabel("number of subscribers")
plt.show()
